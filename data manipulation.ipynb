# %%
import pandas as pd

# %%
filepath = "datafiles/Data.xlsx"
df = pd.read_excel(filepath)

# %%
df
# Out:
#        name  age   department  salary
# 0     Alice   30           HR   50000
# 1       Bob   24  Engineering   60000
# 2   Charlie   26        Sales   55000
# 3     David   35  Engineering   80000
# 4       Eve   29           HR   52000
# 5     Frank   27        Sales   58000
# 6     Grace   31  Engineering   70000
# 7    Hannah   23        Sales   53000
# 8       Ian   34           HR   51000
# 9      Jack   28  Engineering   62000
# 10      Eve   29           HR   52000

# %%
df.head()
# Out:
#       name  age   department  salary
# 0    Alice   30           HR   50000
# 1      Bob   24  Engineering   60000
# 2  Charlie   26        Sales   55000
# 3    David   35  Engineering   80000
# 4      Eve   29           HR   52000

# %%
df.tail(7)
# Out:
#       name  age   department  salary
# 4      Eve   29           HR   52000
# 5    Frank   27        Sales   58000
# 6    Grace   31  Engineering   70000
# 7   Hannah   23        Sales   53000
# 8      Ian   34           HR   51000
# 9     Jack   28  Engineering   62000
# 10     Eve   29           HR   52000

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (11, 4)

# %%
df.columns
# Out:
# Index(['name', 'age', 'department', 'salary'], dtype='object')

# %%
df.describe()
# Out:
#              age        salary
# count  11.000000     11.000000
# mean   28.727273  58454.545455
# std     3.744086   9299.071312
# min    23.000000  50000.000000
# 25%    26.500000  52000.000000
# 50%    29.000000  55000.000000
# 75%    30.500000  61000.000000
# max    35.000000  80000.000000

# %%
df[["age", "salary"]]
# Out:
#     age  salary
# 0    30   50000
# 1    24   60000
# 2    26   55000
# 3    35   80000
# 4    29   52000
# 5    27   58000
# 6    31   70000
# 7    23   53000
# 8    34   51000
# 9    28   62000
# 10   29   52000

# %%
select = df[["age","salary"]]

# %%
select
# Out:
#     age  salary
# 0    30   50000
# 1    24   60000
# 2    26   55000
# 3    35   80000
# 4    29   52000
# 5    27   58000
# 6    31   70000
# 7    23   53000
# 8    34   51000
# 9    28   62000
# 10   29   52000

# %%
df
# Out:
#        name  age   department  salary
# 0     Alice   30           HR   50000
# 1       Bob   24  Engineering   60000
# 2   Charlie   26        Sales   55000
# 3     David   35  Engineering   80000
# 4       Eve   29           HR   52000
# 5     Frank   27        Sales   58000
# 6     Grace   31  Engineering   70000
# 7    Hannah   23        Sales   53000
# 8       Ian   34           HR   51000
# 9      Jack   28  Engineering   62000
# 10      Eve   29           HR   52000

# %%
df.head()
# Out:
#       name  age   department  salary
# 0    Alice   30           HR   50000
# 1      Bob   24  Engineering   60000
# 2  Charlie   26        Sales   55000
# 3    David   35  Engineering   80000
# 4      Eve   29           HR   52000

# %%
df.iloc[3:8]
# Out:
#      name  age   department  salary
# 3   David   35  Engineering   80000
# 4     Eve   29           HR   52000
# 5   Frank   27        Sales   58000
# 6   Grace   31  Engineering   70000
# 7  Hannah   23        Sales   53000

# %%
df.sort_values(by = "salary")
# Out:
#        name  age   department  salary
# 0     Alice   30           HR   50000
# 8       Ian   34           HR   51000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 7    Hannah   23        Sales   53000
# 2   Charlie   26        Sales   55000
# 5     Frank   27        Sales   58000
# 1       Bob   24  Engineering   60000
# 9      Jack   28  Engineering   62000
# 6     Grace   31  Engineering   70000
# 3     David   35  Engineering   80000

# %%
df.sort_values(by = "salary",ascending=False)
# Out:
#        name  age   department  salary
# 3     David   35  Engineering   80000
# 6     Grace   31  Engineering   70000
# 9      Jack   28  Engineering   62000
# 1       Bob   24  Engineering   60000
# 5     Frank   27        Sales   58000
# 2   Charlie   26        Sales   55000
# 7    Hannah   23        Sales   53000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 8       Ian   34           HR   51000
# 0     Alice   30           HR   50000

# %%
df.sort_values(by = "age")
# Out:
#        name  age   department  salary
# 7    Hannah   23        Sales   53000
# 1       Bob   24  Engineering   60000
# 2   Charlie   26        Sales   55000
# 5     Frank   27        Sales   58000
# 9      Jack   28  Engineering   62000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 0     Alice   30           HR   50000
# 6     Grace   31  Engineering   70000
# 8       Ian   34           HR   51000
# 3     David   35  Engineering   80000

# %%
df.sort_values(by = "age",ascending=True)
# Out:
#        name  age   department  salary
# 7    Hannah   23        Sales   53000
# 1       Bob   24  Engineering   60000
# 2   Charlie   26        Sales   55000
# 5     Frank   27        Sales   58000
# 9      Jack   28  Engineering   62000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 0     Alice   30           HR   50000
# 6     Grace   31  Engineering   70000
# 8       Ian   34           HR   51000
# 3     David   35  Engineering   80000

# %%
df.sort_values(by = "age",ascending=False)
# Out:
#        name  age   department  salary
# 3     David   35  Engineering   80000
# 8       Ian   34           HR   51000
# 6     Grace   31  Engineering   70000
# 0     Alice   30           HR   50000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 9      Jack   28  Engineering   62000
# 5     Frank   27        Sales   58000
# 2   Charlie   26        Sales   55000
# 1       Bob   24  Engineering   60000
# 7    Hannah   23        Sales   53000

# %%
df[df["age"] <25]
# Out:
#      name  age   department  salary
# 1     Bob   24  Engineering   60000
# 7  Hannah   23        Sales   53000

# %%
df["age"] <25
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# Name: age, dtype: bool

# %%
df[df["salary"] <55000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df[df["salary"] <55000]
#
# NameError: name 'df' is not defined

# %%
df["salary"] <55000
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10     True
# Name: salary, dtype: bool

# %%
df["location"]="kisumu"

# %%
df
# Out:
#        name  age   department  salary location
# 0     Alice   30           HR   50000   kisumu
# 1       Bob   24  Engineering   60000   kisumu
# 2   Charlie   26        Sales   55000   kisumu
# 3     David   35  Engineering   80000   kisumu
# 4       Eve   29           HR   52000   kisumu
# 5     Frank   27        Sales   58000   kisumu
# 6     Grace   31  Engineering   70000   kisumu
# 7    Hannah   23        Sales   53000   kisumu
# 8       Ian   34           HR   51000   kisumu
# 9      Jack   28  Engineering   62000   kisumu
# 10      Eve   29           HR   52000   kisumu

# %%
def.loc[df["name"] == "Hannah","Location" = "Nairobi"
# Out:
#   Cell In[80], line 1
#     def.loc[df["name"] == "Hannah","Location" = "Nairobi"
#        ^
# SyntaxError: invalid syntax

# %%
df.drop(columns="location")
# Out:
#        name  age   department  salary
# 0     Alice   30           HR   50000
# 1       Bob   24  Engineering   60000
# 2   Charlie   26        Sales   55000
# 3     David   35  Engineering   80000
# 4       Eve   29           HR   52000
# 5     Frank   27        Sales   58000
# 6     Grace   31  Engineering   70000
# 7    Hannah   23        Sales   53000
# 8       Ian   34           HR   51000
# 9      Jack   28  Engineering   62000
# 10      Eve   29           HR   52000

# %%
df.drop(columns="n")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.drop(columns="n")
#
# File ~\anaconda3.1\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df.drop(columns="location[7]")
# Out:
#        name  age   department  salary location        n location(7)
# 0     Alice   30           HR   50000   kisumu  nairobi      kisumu
# 1       Bob   24  Engineering   60000   kisumu  nairobi      kisumu
# 2   Charlie   26        Sales   55000   kisumu  nairobi      kisumu
# 3     David   35  Engineering   80000   kisumu  nairobi      kisumu
# 4       Eve   29           HR   52000   kisumu  nairobi      kisumu
# 5     Frank   27        Sales   58000   kisumu  nairobi      kisumu
# 6     Grace   31  Engineering   70000   kisumu  nairobi      kisumu
# 7    Hannah   23        Sales   53000   kisumu  nairobi      kisumu
# 8       Ian   34           HR   51000   kisumu  nairobi      kisumu
# 9      Jack   28  Engineering   62000   kisumu  nairobi      kisumu
# 10      Eve   29           HR   52000   kisumu  nairobi      kisumu

# %% [markdown]
# grouping and aggregation
# we are to group our data into departments

# %%
grouped=  df.groupby("department")
print(grouped)

# %%
 df.groupby("department")['salary'].sum()
# Out:
# department
# Engineering    272000
# HR             205000
# Sales          166000
# Name: salary, dtype: int64

# %%
df.groupby("department")['salary'].mean()
# Out:
# department
# Engineering    68000.000000
# HR             51250.000000
# Sales          55333.333333
# Name: salary, dtype: float64

# %%
df.groupby('department').agg({'salary':['sum','mean','count','max','std','var','median'],})
# Out:
#              salary                                                        \
#                 sum          mean count    max          std           var
# department
# Engineering  272000  68000.000000     4  80000  9092.121131  8.266667e+07
# HR           205000  51250.000000     4  52000   957.427108  9.166667e+05
# Sales        166000  55333.333333     3  58000  2516.611478  6.333333e+06
#
#
#               median
# department
# Engineering  66000.0
# HR           51500.0
# Sales        55000.0

# %%
df.groupby('department').agg({'age':['sum','mean','count','max','std','var','median'],})
# Out:
#              age
#              sum       mean count max       std        var median
# department
# Engineering  118  29.500000     4  35  4.654747  21.666667   29.5
# HR           122  30.500000     4  34  2.380476   5.666667   29.5
# Sales         76  25.333333     3  27  2.081666   4.333333   26.0
