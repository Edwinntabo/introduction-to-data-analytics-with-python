# %% [markdown]
#    GROUP 1 ASSIGNMENT

# %% [markdown]
# GROUP MEMBERS

# %% [markdown]
# # ALEX MOMANYI

# %% [markdown]
# # JOHN OTIENO

# %% [markdown]
# # JOSHUA OKOTH

# %% [markdown]
# # MARTIN HAYO

# %% [markdown]
# # EDWIN NTABO

# %%
""" Our group has been been consulted to locate and procure house units 
by 2 families  migrating from Kenya to the United States, in the city of
Auburn.
The assignment was based on the following conditions:
1. Price <= $1000000.
2. Bedrooms > 3
3. Bathrooms >= 3
4. Sq. Ft: > 4000
5. floors ==2 
6. Year_built >= 2005
"""
# Out:
# ' Our group has been been consulted to locate and procure house units \nby 2 families  migrating from Kenya to the United States, in the city of\nAuburn.\nThe assignment was based on the following conditions:\n1. Price <= $1000000.\n2. Bedrooms > 3\n3. Bathrooms >= 3\n4. Sq. Ft: > 4000\n5. floors ==2 \n6. Year_built >= 2005\n'

# %% [markdown]
#   # LOADING HOUSING DATA AND CREATING A DATAFRA

# %%
import pandas as pd

# %%
filepath= "DataFiles/house prices in states.csv"
df= pd.read_csv(filepath)

# %%
df
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.760000e+05         3       2.00         1340      1384     3.0
# 1     8.000000e+05         4       3.25         3540    159430     2.0
# 2     2.238888e+06         5       6.50         7270    130017     2.0
# 3     3.240000e+05         3       2.25          998       904     2.0
# 4     5.499000e+05         5       2.75         3060      7015     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4135  3.081667e+05         3       1.75         1510      6360     1.0
# 4136  5.343333e+05         3       2.50         1460      7573     2.0
# 4137  4.169042e+05         3       2.50         3010      7014     2.0
# 4138  2.034000e+05         4       2.00         2090      6630     1.0
# 4139  2.206000e+05         3       2.50         1490      8102     2.0
#
#       Unnamed: 6  Unnamed: 7  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
# DATA INSPECTION

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  Unnamed: 6  \
# 0   376000.0         3       2.00         1340      1384     3.0         NaN
# 1   800000.0         4       3.25         3540    159430     2.0         NaN
# 2  2238888.0         5       6.50         7270    130017     2.0         NaN
# 3   324000.0         3       2.25          998       904     2.0         NaN
# 4   549900.0         5       2.75         3060      7015     1.0         NaN
#
#    Unnamed: 7  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0         NaN          3        1340              0      2008             0
# 1         NaN          3        3540              0      2007             0
# 2         NaN          3        6420            850      2010             0
# 3         NaN          3         798            200      2007             0
# 4         NaN          5        1600           1460      1979             0
#
# ...

# %%
df.tail()
# Out:
#             price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 4135  308166.6667         3       1.75         1510      6360     1.0
# 4136  534333.3333         3       2.50         1460      7573     2.0
# 4137  416904.1667         3       2.50         3010      7014     2.0
# 4138  203400.0000         4       2.00         2090      6630     1.0
# 4139  220600.0000         3       2.50         1490      8102     2.0
#
#       Unnamed: 6  Unnamed: 7  condition  sqft_above  sqft_basement  yr_built  \
# 4135         NaN         NaN          4        1510              0      1954
# 4136         NaN         NaN          3        1460              0      1983
# 4137         NaN         NaN          3        3010              0      2009
# 4138         NaN         NaN          3        1070           1020      1974
# 4139         NaN         NaN          4        1490              0      1990
#
#       yr_renovated             street       city  statezip
# ...

# %%
df.shape
# Out:
# (4140, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4140 entries, 0 to 4139
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          4140 non-null   float64
#  1   bedrooms       4140 non-null   int64
#  2   bathrooms      4140 non-null   float64
#  3   sqft_living    4140 non-null   int64
#  4   sqft_lot       4140 non-null   int64
#  5   floors         4140 non-null   float64
#  6   Unnamed: 6     0 non-null      float64
#  7   Unnamed: 7     0 non-null      float64
#  8   condition      4140 non-null   int64
#  9   sqft_above     4140 non-null   int64
#  10  sqft_basement  4140 non-null   int64
#  11  yr_built       4140 non-null   int64
#  12  yr_renovated   4140 non-null   int64
#  13  street         4140 non-null   object
#  14  city           4140 non-null   object
#  15  statezip       4140 non-null   object
# dtypes: float64(5), int64(8), object(3)
# memory usage: 517.6+ KB

# %%
#Statistical Summary
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.140000e+03  4140.000000  4140.000000   4140.000000  4.140000e+03
# mean   5.530629e+05     3.400483     2.163043   2143.638889  1.469764e+04
# std    5.836865e+05     0.903939     0.784733    957.481621  3.587684e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.200000e+05     3.000000     1.750000   1470.000000  5.000000e+03
# 50%    4.600000e+05     3.000000     2.250000   1980.000000  7.676000e+03
# 75%    6.591250e+05     4.000000     2.500000   2620.000000  1.100000e+04
# max    2.659000e+07     8.000000     6.750000  10040.000000  1.074218e+06
#
#             floors  Unnamed: 6  Unnamed: 7    condition   sqft_above  \
# count  4140.000000         0.0         0.0  4140.000000  4140.000000
# mean      1.514130         NaN         NaN     3.452415  1831.351449
# std       0.534941         NaN         NaN     0.678533   861.382947
# ...

# %%
#DATA CLEANING

# %%
#Inspecting null values in the DataFrame
df.isnull().sum()
# Out:
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# Unnamed: 6       4140
# Unnamed: 7       4140
# condition           0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated        0
# street              0
# city                0
# statezip            0
# dtype: int64

# %%
#Dropping the columns with null values
df.dropna()
# Out:
# Empty DataFrame
# Columns: [price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, Unnamed: 6, Unnamed: 7, condition, sqft_above, sqft_basement, yr_built, yr_renovated, street, city, statezip]
# Index: []

# %%
new_df=df.drop(columns="Unnamed: 6",)

# %%
new_df
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.760000e+05         3       2.00         1340      1384     3.0
# 1     8.000000e+05         4       3.25         3540    159430     2.0
# 2     2.238888e+06         5       6.50         7270    130017     2.0
# 3     3.240000e+05         3       2.25          998       904     2.0
# 4     5.499000e+05         5       2.75         3060      7015     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4135  3.081667e+05         3       1.75         1510      6360     1.0
# 4136  5.343333e+05         3       2.50         1460      7573     2.0
# 4137  4.169042e+05         3       2.50         3010      7014     2.0
# 4138  2.034000e+05         4       2.00         2090      6630     1.0
# 4139  2.206000e+05         3       2.50         1490      8102     2.0
#
#       Unnamed: 7  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
new_df1=new_df.drop(columns="Unnamed: 7",)

# %%
new_df1
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.760000e+05         3       2.00         1340      1384     3.0
# 1     8.000000e+05         4       3.25         3540    159430     2.0
# 2     2.238888e+06         5       6.50         7270    130017     2.0
# 3     3.240000e+05         3       2.25          998       904     2.0
# 4     5.499000e+05         5       2.75         3060      7015     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4135  3.081667e+05         3       1.75         1510      6360     1.0
# 4136  5.343333e+05         3       2.50         1460      7573     2.0
# 4137  4.169042e+05         3       2.50         3010      7014     2.0
# 4138  2.034000e+05         4       2.00         2090      6630     1.0
# 4139  2.206000e+05         3       2.50         1490      8102     2.0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
new_df1.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# dtype: int64

# %%
#Inspecting Diplicates in the DataFrame
new_df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4135    False
# 4136    False
# 4137    False
# 4138    False
# 4139    False
# Length: 4140, dtype: bool

# %%
new_df1.dtypes
# Out:
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# dtype: object

# %%
#DATA MANUPULATION

# %% [markdown]
# DATA SORTING

# %%
new_df1.sort_values(by = "price", ascending=False)
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 3890  26590000.0         3       2.00         1180      7793     1.0
# 3886  12899000.0         3       2.50         2190     11394     1.0
# 1826   7062500.0         5       4.50        10040     37325     2.0
# 2194   4668000.0         5       6.75         9640     13068     1.0
# 2301   4489000.0         4       3.00         6430     27517     2.0
# ...          ...       ...        ...          ...       ...     ...
# 4103         0.0         2       2.25         2130      4920     1.5
# 3960         0.0         4       1.00         1360     13372     1.0
# 4061         0.0         4       1.00         1810      7500     1.0
# 3953         0.0         4       3.00         1990      6180     2.0
# 4107         0.0         4       2.50         4080     18362     2.0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 3890          4        1180              0      1992             0
# ...

# %%
 DATA FILTER

# %%
a= new_df1[new_df1["price"] <=1000000] #filtering housing data on pricing.
a
# Out:
#             price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     376000.0000         3       2.00         1340      1384     3.0
# 1     800000.0000         4       3.25         3540    159430     2.0
# 3     324000.0000         3       2.25          998       904     2.0
# 4     549900.0000         5       2.75         3060      7015     1.0
# 5     320000.0000         3       2.50         2130      6969     2.0
# ...           ...       ...        ...          ...       ...     ...
# 4135  308166.6667         3       1.75         1510      6360     1.0
# 4136  534333.3333         3       2.50         1460      7573     2.0
# 4137  416904.1667         3       2.50         3010      7014     2.0
# 4138  203400.0000         4       2.00         2090      6630     1.0
# 4139  220600.0000         3       2.50         1490      8102     2.0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
b=a[a["bedrooms"] >3] #Filtering housing data based on number of bedrooms
b
# Out:
#             price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1     800000.0000         4       3.25         3540    159430     2.0
# 4     549900.0000         5       2.75         3060      7015     1.0
# 6     875000.0000         4       2.00         2520      6000     1.0
# 7     265000.0000         4       1.00         1940      9533     1.0
# 9     842500.0000         4       2.50         2160      5298     2.5
# ...           ...       ...        ...          ...       ...     ...
# 4123  282766.6667         4       2.00         1700      8640     1.0
# 4128       0.0000         4       2.25         2890     18226     3.0
# 4130  380680.5556         4       2.50         2620      8331     2.0
# 4132  252980.0000         4       2.50         2530      8169     2.0
# 4138  203400.0000         4       2.00         2090      6630     1.0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
c=b[b["bathrooms"]>=3] #Filtering based on number of bathrooms
c
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  \
# 1     800000.0         4       3.25         3540    159430     2.0          3
# 20    900000.0         4       3.25         4700     38412     2.0          3
# 29    372500.0         5       3.00         2480     10090     1.0          3
# 35    950000.0         5       3.00         4530    258746     1.5          4
# 43    330000.0         5       3.00         2100      7715     1.0          3
# ...        ...       ...        ...          ...       ...     ...        ...
# 4080  375000.0         5       3.25         3370      7947     2.0          3
# 4082       0.0         5       3.50         2640      6895     2.0          3
# 4097  471500.0         4       3.00         2370      3672     1.5          5
# 4098       0.0         4       4.25         3500      8750     1.0          5
# 4115       0.0         5       6.25         8020     21738     2.0          3
#
# ...

# %%
d=c[c["sqft_living"]>4000] #filtering based on living space
d
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 20     900000.0         4       3.25         4700     38412     2.0
# 35     950000.0         5       3.00         4530    258746     1.5
# 174    740000.0         5       5.00         5774     31675     1.0
# 442    869000.0         5       3.25         4180     49222     2.0
# 582    490000.0         5       3.50         4460      2975     3.0
# 629    975000.0         5       4.00         4850     36450     2.0
# 670    950000.0         5       3.75         5330      6000     2.0
# 742   1000000.0         4       3.00         4260     18687     2.0
# 805    799950.0         4       3.50         4220    196817     2.0
# 900    569950.0         5       4.50         4850     40902     2.0
# 1003   465000.0         6       3.25         4250     23326     1.0
# 1019   565000.0         7       4.50         4140      9066     1.0
# 1057   700000.0         4       3.50         4490      5099     2.0
# ...

# %%
d.shape
# Out:
# (50, 14)

# %%
e=d[d["floors"]==2]
e
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 20     900000.0         4       3.25         4700     38412     2.0
# 442    869000.0         5       3.25         4180     49222     2.0
# 629    975000.0         5       4.00         4850     36450     2.0
# 670    950000.0         5       3.75         5330      6000     2.0
# 742   1000000.0         4       3.00         4260     18687     2.0
# 805    799950.0         4       3.50         4220    196817     2.0
# 900    569950.0         5       4.50         4850     40902     2.0
# 1057   700000.0         4       3.50         4490      5099     2.0
# 1095   950000.0         4       3.50         4140     13392     2.0
# 1146   625000.0         4       3.25         4240     25639     2.0
# 1257   870000.0         4       3.00         4500     21780     2.0
# 1262   687000.0         4       3.25         4400    186846     2.0
# 1344   960000.0         4       3.00         4590      9150     2.0
# ...

# %%
e.shape
# Out:
# (38, 14)

# %%
f=e[e["yr_built"]>=2005] #Filtering based on year of build.
f
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  \
# 670   950000.0         5       3.75         5330      6000     2.0          3
# 1057  700000.0         4       3.50         4490      5099     2.0          3
# 1465  765000.0         4       3.00         4410      5104     2.0          3
# 3114  550000.0         4       3.50         4150     16197     2.0          3
# 3327  920000.0         4       3.50         4080     10666     2.0          3
# 3434  835000.0         4       4.25         4930     25714     2.0          3
# 3922       0.0         5       4.50         4630      6324     2.0          3
# 3923       0.0         5       4.00         4430      9000     2.0          3
# 3925       0.0         4       4.50         5030     11023     2.0          3
# 3929       0.0         4       3.50         4210     10308     2.0          3
#
#       sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
g=f[f["city"]=="Auburn"] #Finally, 2 house units found in the city of Aurbun

# %%
g
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  condition  \
# 3114  550000.0         4       3.50         4150     16197     2.0          3
# 3434  835000.0         4       4.25         4930     25714     2.0          3
#
#       sqft_above  sqft_basement  yr_built  yr_renovated             street  \
# 3114        4150              0      2006             0  11824 SE 290th Pl
# 3434        4930              0      2005             0  32805 145th Pl SE
#
#         city  statezip
# 3114  Auburn  WA 98092
# 3434  Auburn  WA 98092
